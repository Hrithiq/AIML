# %%
# !pip install Document
# !pip install Workbook

# %%
from docx import Document
from openpyxl import Workbook

# Create a new Word document
doc = Document()

# Add a title to the document
doc.add_heading('CMA Intermediate Syllabus', level=1)

# Data for the table
data = [
    ["Group", "Subject", "Section", "Content", "Weightage", "Module", "Studied", "Revised", "Test"],
    ["Group 1", "Business Law and Ethics", "Commercial Laws", "Laws of Contracts", "10%", "", "", "", ""],
    ["", "", "", "Laws relating to Sale of Goods", "5%", "", "", "", ""],
    ["", "", "", "Negotiable Instruments Act, 1881", "5%", "", "", "", ""],
    ["", "", "", "Indian Partnership Act, 1932", "5%", "", "", "", ""],
    ["", "", "", "Limited Liability Partnership Act, 2008", "5%", "", "", "", ""],
    ["", "Industrial Laws", "Factories Act, 1948", "10%", "", "", "", ""],
    ["", "", "", "Payment of Gratuity Act, 1972", "5%", "", "", "", ""],
    ["", "", "", "Employees Provident Fund and Miscellaneous Provisions Act, 1952", "5%", "", "", "", ""],
    ["", "", "", "Employees State Insurance Act, 1948", "5%", "", "", "", ""],
    ["", "", "", "Code on Wages, 2019", "5%", "", "", "", ""],
    ["", "Companies Act, 2013", "", "Corporate Law", "40%", "", "", "", ""],
    ["", "", "Business Ethics", "Business Ethics and Emotional Intelligence", "15%", "", "", "", ""],
    ["", "Financial Accounting", "Fundamentals of Accounting", "Introduction and Basics", "15%", "", "", "", ""],
    ["", "", "", "Accounting for Special Transactions", "10%", "", "", "", ""],
    ["", "", "Preparation of Financial Statements", "Final Accounts of Commercial Organisations, Not-for-Profit Organisations, and from Incomplete Records", "20%", "", "", "", ""],
    # Add more data for Group 1 and Group 2 here...
]

# Add the table to the Word document
table = doc.add_table(rows=1, cols=len(data[0]))
table.style = 'Table Grid'
hdr_cells = table.rows[0].cells
for i, header in enumerate(data[0]):
    hdr_cells[i].text = header
for row in data[1:]:
    row_cells = table.add_row().cells
    for i, cell in enumerate(row):
        row_cells[i].text = cell

# Save the Word document
doc.save("CMA_Intermediate_Syllabus.docx")

# Create a new Excel workbook
wb = Workbook()
ws = wb.active

# Add data to the Excel workbook
for row in data:
    ws.append(row)

# Save the Excel workbook
wb.save(r"C:\Users\hrith\OneDrive\Desktop\Project Manas\CMA_Intermediate_Syllabus.xlsx")

# %%
import pandas as pd

# Data for the table
data = [
    ["Group", "Subject", "Section", "Content", "Weightage", "Module", "Studied", "Revised", "Test"],
    ["Group 1", "Business Law and Ethics", "Commercial Laws", "Laws of Contracts", "10%", "", "", "", ""],
    ["", "", "", "Laws relating to Sale of Goods", "5%", "", "", "", ""],
    # Add more Group 1 data here...
    ["Group 2", "Operations Management & Strategic Management", "Operations Management", "Introduction, Operations Planning, Designing of Operational Systems and Control, Production Planning and Control, Productivity Management and Quality Management, Project Management, Economics of Maintenance and Spares Management", "70%", "", "", "", ""],
    ["", "", "", "Strategic Management", "30%", "", "", "", ""],
    # Add more Group 2 data here...
]

# Create a DataFrame from the data
df = pd.DataFrame(data[1:], columns=data[0])

# Save the DataFrame to an Excel file
df.to_excel(r"C:\Users\hrith\OneDrive\Desktop\Project Manas\CMA_Intermediate_Syllabus_pd.xlsx", index=False)

# %%
import pandas as pd
from docx import Document
from docx.shared import Pt

# Data for Group 1
data_group1 = [
    ["Business Law and Ethics", "Commercial Laws", "Laws of Contracts", "10%", "", "", ""],
    ["", "", "Laws relating to Sale of Goods", "5%", "", "", ""],
    ["", "", "Negotiable Instruments Act, 1881", "5%", "", "", ""],
    ["", "", "Indian Partnership Act, 1932", "5%", "", "", ""],
    ["", "", "Limited Liability Partnership Act, 2008", "5%", "", "", ""],
    ["", "Industrial Laws", "Factories Act, 1948", "10%", "", "", ""],
    ["", "", "Payment of Gratuity Act, 1972", "5%", "", "", ""],
    ["", "", "Employees Provident Fund and Miscellaneous Provisions Act, 1952", "5%", "", "", ""],
    ["", "", "Employees State Insurance Act, 1948", "5%", "", "", ""],
    ["", "", "Code on Wages, 2019", "5%", "", "", ""],
    ["", "Companies Act, 2013", "Corporate Law", "40%", "", "", ""],
    ["", "Business Ethics", "Business Ethics and Emotional Intelligence", "15%", "", "", ""],
    ["Financial Accounting", "Fundamentals of Accounting", "Introduction and Basics", "15%", "", "", ""],
    ["", "", "Accounting for Special Transactions", "10%", "", "", ""],
    ["", "Preparation of Financial Statements", "Final Accounts of Commercial Organisations, Not-for-Profit Organisations, and from Incomplete Records", "20%", "", "", ""],
    ["", "Partnership Accounts", "All Topics", "20%", "", "", ""],
    ["", "Lease, Branch, and Departmental Accounts etc.", "Lease Accounting, Branch (including Foreign Branch) and Departmental Accounts, Insurance Claim for Loss of Stock and Loss of Profit, Hire Purchase and Installment Sale Transactions", "15%", "", "", ""],
    ["", "Accounting Standards", "Detailed Topics", "20%", "", "", ""],
    ["Direct and Indirect Taxes", "Basics of Income Tax Act", "Introduction and Basic Concepts", "10%", "", "", ""],
    ["", "Heads of Income", "Various Heads", "25%", "", "", ""],
    ["", "Total Income and Tax Liability", "Calculation for Individuals & HUF", "15%", "", "", ""],
    ["", "Indirect Taxation", "Concept of Indirect Taxes", "5%", "", "", ""],
    ["", "", "Goods and Services Tax (GST) Laws", "35%", "", "", ""],
    ["", "", "Customs Act", "10%", "", "", ""],
    ["Cost Accounting", "Introduction to Cost Accounting", "Elements of Cost, Cost Accounting Standards, Cost Book Keeping", "40%", "", "", ""],
    ["", "Methods of Costing", "Various Methods", "30%", "", "", ""],
    ["", "Cost Accounting Techniques", "Detailed Techniques", "30%", "", "", ""]
]

# Data for Group 2
data_group2 = [
    ["Operations Management & Strategic Management", "Operations Management", "Introduction, Operations Planning, Designing of Operational Systems and Control, Production Planning and Control, Productivity Management and Quality Management, Project Management, Economics of Maintenance and Spares Management", "70%", "", "", ""],
    ["", "", "Strategic Management", "30%", "", "", ""],
    ["Corporate Accounting and Auditing", "Corporate Accounting", "Accounting for Shares and Debentures, Preparation of the Statement of Profit and Loss and Balance Sheet (As per Schedule III of Companies Act, 2013), Cash Flow Statement, Accounts of Banking, Electricity and Insurance Companies, Accounting Standards", "50%", "", "", ""],
    ["", "Auditing", "Basic Concepts of Auditing, Provisions Relating to Audit under Companies Act, 2013, Auditing of Different Types of Undertakings", "50%", "", "", ""],
    ["Financial Management and Business Data Analytics", "Financial Management", "Fundamentals of Financial Management, Institutions and Instruments in Financial Markets, Tools for Financial Analyses, Sources of Finance and Cost of Capital, Capital Budgeting, Working Capital Management, Financing Decision of a Firm", "80%", "", "", ""],
    ["", "Business Data Analytics", "Introduction to Data Science for Business Decision-making, Data Processing, Organisation, Cleaning, and Validation, Data Presentation: Visualisation and Graphical Presentation, Data Analysis and Modelling", "20%", "", "", ""],
    ["Management Accounting", "Introduction to Management Accounting", "Overview and Basics", "5%", "", "", ""],
    ["", "Activity Based Costing", "Detailed Concepts", "10%", "", "", ""],
    ["", "Marginal Costing", "Concepts, Cost-Volume-Profit Analysis, Break-Even Charts and Profit Charts, Multiple Product Break Even Analysis, Differential Cost Analysis, Marginal Costing Vs. Absorption Costing", "30%", "", "", ""],
    ["", "", "Applications of Marginal Costing in Short Term Decision Making, Pricing Decision, Make or Buy decisions, Accept an Order or Reject, Optimum Utilization of Factors of Production (Limiting Factor Analysis), Replacement Decision, Evaluation of Alternative Choices, Subcontracting and Ancillarisation, Expansion of Business, Shutdown or Continue", "", "", "", ""],
    ["", "Transfer Pricing", "Concept, Methods and Techniques, Divisional Performance and Problem of Goal Congruence, Determination of Inter-departmental or Inter-company Transfer Price, International Transfer Pricing", "10%", "", "", ""],
    ["", "Standard Costing and Variance Analysis", "Material and Labour Variances, Variable Overhead Variance, Fixed Overhead Variance, Sales Variance, Interpretation of Variances and Inferences Drawn", "15%", "", "", ""],
    ["", "Forecasting, Budgeting and Budgetary Control", "Introduction, Rationale for Budgets, General Principles in the Budgetary Process, Formulation of various types of Budgets", "15%", "", "", ""],
    ["", "Divisional Performance Measurement", "Organizations with Multiple Divisions, Benefits of Decentralization, DuPont Analysis, Divisional Performance Measurement tools – ROI, Residual Income, Economic Value Added – Definition, EVA Centre, EVA Drivers, Introduction to Learning Curve, Balanced Score Card for Variable Pay Management", "10%", "", "", ""],
    ["", "Responsibility Accounting", "Concept of Cost, Revenue, Profit and Responsibility Centres, Preparation of Responsibility Report", "5%", "", "", ""],
    ["", "Decision Theory", "Decision-Making under Certainty, Decisions Making under Risk, Decision-Making under Uncertainty, Decision Tree", "10%", "", "", ""]
]

# Create a DataFrame for each group
df_group1 = pd.DataFrame(data_group1, columns=["Subject", "Section", "Content", "Weightage", "Studied Module", "Revised", "Test"])
df_group2 = pd.DataFrame(data_group2, columns=["Subject", "Section", "Content", "Weightage", "Studied Module", "Revised", "Test"])

# Create a Word document
doc = Document()

# Function to add a table to the document
def add_table_to_doc(df, group_title):
    doc.add_heading(group_title, level=3)
    table = doc.add_table(rows=1, cols=len(df.columns))
    hdr_cells = table.rows[0].cells
    for i, column in enumerate(df.columns):
        hdr_cells[i].text = column

    for index, row in df.iterrows():
        row_cells = table.add_row().cells
        for i, item in enumerate(row):
            row_cells[i].text = str(item)

    # Adjust font size
    for row in table.rows:
        for cell in row.cells:
            for paragraph in cell.paragraphs:
                for run in paragraph.runs:
                    run.font.size = Pt(10)

# Add tables to the document
add_table_to_doc(df_group1, "Group 1")
add_table_to_doc(df_group2, "Group 2")

# Save the document
doc.save("CMA_Intermediate_Syllabus_pt.docx")
